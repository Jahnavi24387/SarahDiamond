# %%
# load dataset
from pycaret.datasets import get_data
diabetes = get_data('diabetes')

# init setup
from pycaret.classification import *
clf1 = setup(data = diabetes, target = 'Class variable', session_id = 123)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6752\1826765540.py in <cell line: 7>()
#       5 # init setup
#       6 from pycaret.classification import *
# ----> 7 clf1 = setup(data = diabetes, target = 'Class variable', session_id = 123)
#
# E:\pycaret-mlops-master\pycaret-mlops-master\venv\lib\site-packages\pycaret\classification\functional.py in setup(data, data_func, target, index, train_size, test_data, ordinal_features, numeric_features, categorical_features, date_features, text_features, ignore_features, keep_features, preprocess, create_date_columns, imputation_type, numeric_imputation, categorical_imputation, iterative_imputation_iters, numeric_iterative_imputer, categorical_iterative_imputer, text_features_method, max_encoding_ohe, encoding_method, rare_to_value, rare_value, polynomial_features, polynomial_degree, low_variance_threshold, group_features, group_names, drop_groups, remove_multicollinearity, multicollinearity_threshold, bin_numeric_features, remove_outliers, outliers_method, outliers_threshold, fix_imbalance, fix_imbalance_method, transformation, transformation_method, normalize, normalize_method, pca, pca_method, pca_components, feature_selection, feature_selection_method, feature_selection_estimator, n_features_to_select, custom_pipeline, custom_pipeline_position, data_split_shuffle, data_split_stratify, fold_strategy, fold, fold_shuffle, fold_groups, n_jobs, use_gpu, html, session_id, system_log, log_experiment, experiment_name, experiment_custom_tags, log_plots, log_profile, log_data, verbose, memory, profile, profile_kwargs)
#     600     exp = _EXPERIMENT_CLASS()
#     601     set_current_experiment(exp)
# --> 602     return exp.setup(
#     603         data=data,
#     604         data_func=data_func,
#
# E:\pycaret-mlops-master\pycaret-mlops-master\venv\lib\site-packages\pycaret\classification\oop.py in setup(self, data, data_func, target, index, train_size, test_data, ordinal_features, numeric_features, categorical_features, date_features, text_features, ignore_features, keep_features, preprocess, create_date_columns, imputation_type, numeric_imputation, categorical_imputation, iterative_imputation_iters, numeric_iterative_imputer, categorical_iterative_imputer, text_features_method, max_encoding_ohe, encoding_method, rare_to_value, rare_value, polynomial_features, polynomial_degree, low_variance_threshold, group_features, group_names, drop_groups, remove_multicollinearity, multicollinearity_threshold, bin_numeric_features, remove_outliers, outliers_method, outliers_threshold, fix_imbalance, fix_imbalance_method, transformation, transformation_method, normalize, normalize_method, pca, pca_method, pca_components, feature_selection, feature_selection_method, feature_selection_estimator, n_features_to_select, custom_pipeline, custom_pipeline_position, data_split_shuffle, data_split_stratify, fold_strategy, fold, fold_shuffle, fold_groups, n_jobs, use_gpu, html, session_id, system_log, log_experiment, experiment_name, experiment_custom_tags, log_plots, log_profile, log_data, engine, verbose, memory, profile, profile_kwargs)
#     720         self.fold_groups_param = fold_groups
#     721
# --> 722         self._initialize_setup(
#     723             n_jobs=n_jobs,
#     724             use_gpu=use_gpu,
#
# E:\pycaret-mlops-master\pycaret-mlops-master\venv\lib\site-packages\pycaret\internal\pycaret_experiment\tabular_experiment.py in _initialize_setup(self, n_jobs, use_gpu, html, session_id, system_log, log_experiment, experiment_name, memory, verbose)
#     328         self.logger.info(f"self._variable_keys: {self._variable_keys}")
#     329
# --> 330         self._check_environment()
#     331
#     332         # Set up GPU usage ========================================= >>
#
# E:\pycaret-mlops-master\pycaret-mlops-master\venv\lib\site-packages\pycaret\internal\pycaret_experiment\pycaret_experiment.py in _check_environment(self)
#     119
#     120         self.logger.info("Checking libraries")
# --> 121         self.logger.info(show_versions(logger=self.logger))
#     122
#     123     def setup(self, *args, **kwargs) -> None:
#
# E:\pycaret-mlops-master\pycaret-mlops-master\venv\lib\site-packages\pycaret\utils\_show_versions.py in show_versions(optional, logger)
#     169     if optional:
#     170         print_func(f"{prefix}PyCaret optional dependencies:")  # noqa: T001
# --> 171         optional_deps_info = _get_deps_info(logger=logger, optional=True)
#     172         for k, stat in optional_deps_info.items():
#     173             print_func("{k:>20}: {stat}".format(k=k, stat=stat))  # noqa: T001
#
# E:\pycaret-mlops-master\pycaret-mlops-master\venv\lib\site-packages\pycaret\utils\_show_versions.py in _get_deps_info(optional, logger)
#     128     for modname in deps:
#     129         try:
# --> 130             ver = get_module_version(modname)
#     131             if not ver:
#     132                 ver = "Installed but version unavailable"
#
# E:\pycaret-mlops-master\pycaret-mlops-master\venv\lib\site-packages\pycaret\utils\_dependencies.py in get_module_version(modname)
#      79 def get_module_version(modname: str) -> Optional[LooseVersion]:
#      80     """Raises a ValueError if module is not installed"""
# ---> 81     version = _get_module_version(modname)
#      82     if version is False:
#      83         raise ValueError(f"Module '{modname}' is not installed.")
#
# E:\pycaret-mlops-master\pycaret-mlops-master\venv\lib\site-packages\pycaret\utils\_dependencies.py in _get_module_version(modname)
#      73     if modname not in installed_modules:
#      74         # Fallback. This should never happen unless module is not present
# ---> 75         installed_modules[modname] = _try_import_and_get_module_version(modname)
#      76     return installed_modules[modname]
#      77
#
# E:\pycaret-mlops-master\pycaret-mlops-master\venv\lib\site-packages\pycaret\utils\_dependencies.py in _try_import_and_get_module_version(modname)
#      26             if logger:
#      27                 with redirect_output(logger):
# ---> 28                     mod = import_module(modname)
#      29             else:
#      30                 mod = import_module(modname)
#
# ~\AppData\Local\Programs\Python\Python39\lib\importlib\__init__.py in import_module(name, package)
#     125                 break
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#     129
#
# ~\AppData\Local\Programs\Python\Python39\lib\importlib\_bootstrap.py in _gcd_import(name, package, level)
#
# ~\AppData\Local\Programs\Python\Python39\lib\importlib\_bootstrap.py in _find_and_load(name, import_)
#
# ~\AppData\Local\Programs\Python\Python39\lib\importlib\_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# ~\AppData\Local\Programs\Python\Python39\lib\importlib\_bootstrap.py in _load_unlocked(spec)
#
# ~\AppData\Local\Programs\Python\Python39\lib\importlib\_bootstrap_external.py in exec_module(self, module)
#
# ~\AppData\Local\Programs\Python\Python39\lib\importlib\_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# E:\pycaret-mlops-master\pycaret-mlops-master\venv\lib\site-packages\gradio\__init__.py in <module>
#       1 import pkgutil
#       2
# ----> 3 import gradio.components as components
#       4 import gradio.inputs as inputs
#       5 import gradio.outputs as outputs
#
# E:\pycaret-mlops-master\pycaret-mlops-master\venv\lib\site-packages\gradio\components\__init__.py in <module>
# ----> 1 from gradio.components.annotated_image import AnnotatedImage
#       2 from gradio.components.audio import Audio
#       3 from gradio.components.bar_plot import BarPlot
#       4 from gradio.components.base import (
#       5     Column,
#
# E:\pycaret-mlops-master\pycaret-mlops-master\venv\lib\site-packages\gradio\components\annotated_image.py in <module>
#      11
#      12 from gradio import utils
# ---> 13 from gradio.components.base import IOComponent, _Keywords
#      14 from gradio.deprecation import warn_style_method_deprecation
#      15 from gradio.events import (
#
# E:\pycaret-mlops-master\pycaret-mlops-master\venv\lib\site-packages\gradio\components\base.py in <module>
#      27
#      28 from gradio import processing_utils, utils
# ---> 29 from gradio.blocks import Block, BlockContext
#      30 from gradio.deprecation import warn_deprecation, warn_style_method_deprecation
#      31 from gradio.events import (
#
# E:\pycaret-mlops-master\pycaret-mlops-master\venv\lib\site-packages\gradio\blocks.py in <module>
#      26 from packaging import version
#      27
# ---> 28 from gradio import (
#      29     analytics,
#      30     components,
#
# E:\pycaret-mlops-master\pycaret-mlops-master\venv\lib\site-packages\gradio\networking.py in <module>
#      16
#      17 from gradio.exceptions import ServerFailedToStartError
# ---> 18 from gradio.routes import App
#      19 from gradio.tunneling import Tunnel
#      20
#
# E:\pycaret-mlops-master\pycaret-mlops-master\venv\lib\site-packages\gradio\routes.py in <module>
#      95
#      96
# ---> 97 templates = Jinja2Templates(directory=STATIC_TEMPLATE_LIB)
#      98 templates.env.filters["toorjson"] = toorjson
#      99
#
# E:\pycaret-mlops-master\pycaret-mlops-master\venv\lib\site-packages\starlette\templating.py in __init__(self, directory)
#      51     def __init__(self, directory: str) -> None:
#      52         assert jinja2 is not None, "jinja2 must be installed to use Jinja2Templates"
# ---> 53         self.env = self.get_env(directory)
#      54
#      55     def get_env(self, directory: str) -> "jinja2.Environment":
#
# E:\pycaret-mlops-master\pycaret-mlops-master\venv\lib\site-packages\starlette\templating.py in get_env(self, directory)
#      54
#      55     def get_env(self, directory: str) -> "jinja2.Environment":
# ---> 56         @jinja2.contextfunction
#      57         def url_for(context: dict, name: str, **path_params: typing.Any) -> str:
#      58             request = context["request"]
#
# AttributeError: module 'jinja2' has no attribute 'contextfunction'

# %%
# !pip uninstall flask
# !pip uninstall jinja2
# !pip install flask
# Out:
# ^C
# ^C
